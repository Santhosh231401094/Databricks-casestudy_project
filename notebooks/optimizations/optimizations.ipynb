# %% [markdown]
# # dim_customer

# %%
# %sql
-- Check current table details
DESCRIBE DETAIL retailnova.gold.dim_customer;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
-- Enable Optimized Writes
ALTER TABLE retailnova.gold.dim_customer
SET TBLPROPERTIES (
  'delta.autoOptimize.optimizeWrite' = 'true'
);

# %%
# %sql
-- Enable Auto Compaction
ALTER TABLE retailnova.gold.dim_customer
SET TBLPROPERTIES (
  'delta.autoOptimize.autoCompact' = 'true'
);

# %%
# %sql
-- Liquid Clustering
ALTER TABLE retailnova.gold.dim_customer
CLUSTER BY (customer_id);

# %%
# %sql
-- Optimize existing files
OPTIMIZE retailnova.gold.dim_customer;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
-- Remove obsolete files after the standard 7-day retention period
VACUUM retailnova.gold.dim_customer;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th></tr></thead><tbody><tr><td></td></tr></tbody></table></div>

# %% [markdown]
# # dim_product

# %%
# %sql
DESCRIBE DETAIL retailnova.gold.dim_product;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
ALTER TABLE retailnova.gold.dim_product
SET TBLPROPERTIES (
  'delta.autoOptimize.optimizeWrite' = 'true'
);

# %%
# %sql
ALTER TABLE retailnova.gold.dim_product
SET TBLPROPERTIES (
  'delta.autoOptimize.autoCompact' = 'true'
);

# %%
# %sql
ALTER TABLE retailnova.gold.dim_product
CLUSTER BY (product_id);

# %%
# %sql
OPTIMIZE retailnova.gold.dim_product;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
VACUUM retailnova.gold.dim_product;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th></tr></thead><tbody><tr><td></td></tr></tbody></table></div>

# %% [markdown]
# # fact_sales

# %%
# %sql
DESCRIBE DETAIL retailnova.gold.fact_sales;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
ALTER TABLE retailnova.gold.fact_sales
SET TBLPROPERTIES (
  'delta.autoOptimize.optimizeWrite' = 'true'
);

# %%
# %sql
ALTER TABLE retailnova.gold.fact_sales
SET TBLPROPERTIES (
  'delta.autoOptimize.autoCompact' = 'true'
);

# %%
# %sql
ALTER TABLE retailnova.gold.fact_sales
CLUSTER BY (date_key, product_key);

# %%
# %sql
OPTIMIZE retailnova.gold.fact_sales;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# %sql
VACUUM retailnova.gold.fact_sales;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th></tr></thead><tbody><tr><td></td></tr></tbody></table></div>

# %%
# %sql
SHOW TBLPROPERTIES retailnova.gold.dim_customer;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
